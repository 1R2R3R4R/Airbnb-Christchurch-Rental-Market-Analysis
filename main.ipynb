# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Airbnb_Oct25_Jun26.csv")

print("Shape of the final dataset:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nFirst 5 rows:")
print(df.head())
# Out:
# Shape of the final dataset: (28795, 19)
#
# Columns: ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'number_of_reviews_ltm', 'license', 'month_year']
#
# First 5 rows:
#              id                            name      host_id  \
# 0  4.018376e+07        Ensuite Cabin (Sleeps 6)   98758734.0
# 1  1.149730e+18  Handy city center. Simple room  298456605.0
# 2  1.097487e+06      Heritage Magic in Merivale    4993285.0
# 3  1.339650e+18         Settle into the sun set   54299306.0
# 4  1.211070e+18             Eco Spa-bath Studio  179297759.0
#
#                   host_name neighbourhood_group   neighbourhood   latitude  \
# 0  North South Holiday Park   Christchurch City   Harewood Ward -43.470020
# 1                      Tony   Christchurch City    Central Ward -43.532700
# 2                  Paulette   Christchurch City  Fendalton Ward -43.511490
# 3                    Sarena   Christchurch City    Burwood Ward -43.482864
# 4                      Peng   Christchurch City  Riccarton Ward -43.538437
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  172.570880     Private room    NaN             1.0                  0
# 1  172.664030     Private room    NaN             1.0                 25
# 2  172.625400     Private room  166.0             1.0                230
# 3  172.668660  Entire home/apt    NaN             2.0                  2
# 4  172.578953     Private room  126.0             1.0                  8
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0         NaN                NaN                              20
# 1  15/07/2025               1.47                               6
# 2    3/3/2025               2.17                               1
# 3  26/04/2025               0.35                               1
# 4    1/3/2025               0.58                              20
#
#    availability_365  number_of_reviews_ltm  license month_year
# 0               317                      0      NaN    2025-10
# 1                 0                     21      NaN    2025-10
# 2               221                     14      NaN    2025-10
# 3                 0                      2      NaN    2025-10
# 4               359                      5      NaN    2025-10

# %%
print("\n=== STASTICAL VALUES ===") 
print(df.describe(include='all').round(2))
print("\n=== CATEGORICAL COLUMNS ===") 
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
print("\n=== MISSING VALUES ===") 
print(df.isnull().sum())
# Out:
# === STASTICAL VALUES ===
#                   id                  name       host_id            host_name  \
# count   2.879500e+04                 28795  2.879500e+04                28794
# unique           NaN                  4854           NaN                 1422
# top              NaN  Room in Christchurch           NaN  Paula Kat Charlotte
# freq             NaN                    23           NaN                 1561
# mean    9.030626e+17                   NaN  1.990276e+15                  NaN
# std     5.945297e+17                   NaN  5.788805e+16                  NaN
# min     2.040500e+05                   NaN  5.738200e+04                  NaN
# 25%     5.237109e+07                   NaN  6.395537e+07                  NaN
# 50%     1.089970e+18                   NaN  1.721473e+08                  NaN
# 75%     1.393915e+18                   NaN  4.471452e+08                  NaN
# max     1.709890e+18                   NaN  1.700000e+18                  NaN
#
#        neighbourhood_group neighbourhood  latitude  longitude  \
# count                28795         28795  28795.00   28795.00
# unique                   1            16       NaN        NaN
# top      Christchurch City  Central Ward       NaN        NaN
# freq                 28795         10554       NaN        NaN
# mean                   NaN           NaN    -43.56     172.66
# std                    NaN           NaN      0.08       0.10
# min                    NaN           NaN    -43.87     172.43
# 25%                    NaN           NaN    -43.56     172.62
# 50%                    NaN           NaN    -43.53     172.64
# 75%                    NaN           NaN    -43.52     172.66
# max                    NaN           NaN    -43.42     173.10
#
#               room_type     price  minimum_nights  number_of_reviews  \
# count             28795  18128.00        28758.00           28795.00
# unique                4       NaN             NaN                NaN
# top     Entire home/apt       NaN             NaN                NaN
# freq              22765       NaN             NaN                NaN
# mean                NaN    260.20            1.79              70.39
# std                 NaN    943.72            5.51             120.51
# min                 NaN     27.00            1.00               0.00
# 25%                 NaN    140.00            1.00               5.00
# 50%                 NaN    205.00            1.00              26.00
# 75%                 NaN    284.00            2.00              85.00
# max                 NaN  43654.00          365.00            1584.00
#
#        last_review  reviews_per_month  calculated_host_listings_count  \
# count        26168           26168.00                        28795.00
# unique         745                NaN                             NaN
# top     28/02/2026                NaN                             NaN
# freq           364                NaN                             NaN
# mean           NaN               2.35                           58.30
# std            NaN               2.19                          188.53
# min            NaN               0.01                            1.00
# 25%            NaN               0.76                            1.00
# 50%            NaN               1.70                            3.00
# 75%            NaN               3.33                           47.00
# max            NaN              16.57                         1586.00
#
#         availability_365  number_of_reviews_ltm  license month_year
# count           28795.00                28795.0      0.0      28795
# unique               NaN                    NaN      NaN          9
# top                  NaN                    NaN      NaN    2026-06
# freq                 NaN                    NaN      NaN       3469
# mean              203.80                   19.0      NaN        NaN
# std               112.28                   23.5      NaN        NaN
# min                 0.00                    0.0      NaN        NaN
# 25%               109.00                    2.0      NaN        NaN
# 50%               225.00                   10.0      NaN        NaN
# 75%               302.00                   27.0      NaN        NaN
# max               365.00                  185.0      NaN        NaN
#
# === CATEGORICAL COLUMNS ===
#
# === MISSING VALUES ===
# id                                    0
# name                                  0
# host_id                               0
# host_name                             1
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                             10667
# minimum_nights                       37
# number_of_reviews                     0
# last_review                        2627
# reviews_per_month                  2627
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           28795
# month_year                            0
# dtype: int64
# C:\Users\koushika\AppData\Local\Temp\ipykernel_9348\3125651976.py:4: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = df.select_dtypes(include=['object', 'category']).columns

# %%
df_price = df[df['price'] <= 1000].copy()

plt.figure(figsize=(9, 5))
plt.hist(df_price['price'].dropna(), bins=40, edgecolor='black', color='steelblue')
plt.title("Branch 1: Price Distribution (Christchurch ≤ $1000)")
plt.xlabel("Price (NZD)")
plt.ylabel("Number of Listings")
plt.show()

# %%
# BRANCH 2: Price by month (example)
plt.figure(figsize=(10, 5))
df_price.groupby('month_year')['price'].mean().plot(kind='bar', color='darkorange')
plt.title("Branch 2: Average Price by Month")
plt.xlabel("Month-Year")
plt.ylabel("Average Price (NZD)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 1. Convert last_review to datetime (keep this)
df['last_review'] = pd.to_datetime(df['last_review'], errors='coerce')

# 2. Mapping of month_year → real scrape date from Inside Airbnb
# Why this mapping?  
# Each monthly file was collected on a specific day.  
# “Days since last review” only makes sense when measured against the actual day the data was scraped.
scrape_dates = {
    '2025-10': '2025-10-05',
    '2025-11': '2025-11-07',
    '2025-12': '2025-12-11',
    '2026-01': '2026-01-16',
    '2026-02': '2026-02-13',
    '2026-03': '2026-03-17',
    '2026-04': '2026-04-16',
    '2026-05': '2026-05-23',
    '2026-06': '2026-06-19'
}

# 3. Create the correct reference date for every row
df['ref_date'] = pd.to_datetime(df['month_year'].map(scrape_dates))

# 4. Calculate days since last review using the correct date for that month
df['days_since_last_review'] = (df['ref_date'] - df['last_review']).dt.days
# Out:
# C:\Users\koushika\AppData\Local\Temp\ipykernel_9348\3111367473.py:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['last_review'] = pd.to_datetime(df['last_review'], errors='coerce')

# %%
df_recent = df[df['days_since_last_review'] <= 100].copy()

plt.figure(figsize=(9, 5))
plt.hist(df_recent['days_since_last_review'].dropna(), bins=40, edgecolor='black', color='seagreen')
plt.title("Branch 3: Days Since Last Review (≤ 100 days)")
plt.xlabel("Days Since Last Review")
plt.ylabel("Number of Listings")
plt.xlim(left=0)
plt.show()

# %%
# BRANCH 4: Rank by number of reviews → Top 10% 
df['Rank'] = df['number_of_reviews'].rank(ascending=False, method='first')
top_10_percent = int(len(df) * 0.10)

df_top10 = df[df['Rank'] <= top_10_percent].copy()

print("Total listings in the dataset:", len(df))
print("Top 10% cutoff (Rank ≤ ):", top_10_percent)
print("Number of listings in Top 10%:", len(df_top10))

print("\n=== Top 10% most reviewed listings ===")
print(df_top10[['Rank', 'name', 'neighbourhood_group', 'month_year', 'price', 'number_of_reviews']]
      .sort_values('Rank')
      .head(20))
# Out:
# Total listings in the dataset: 28795
# Top 10% cutoff (Rank ≤ ): 2879
# Number of listings in Top 10%: 2879
#
# === Top 10% most reviewed listings ===
#        Rank                                           name  \
# 26541   1.0                              lazy porch studio
# 23613   2.0                              lazy porch studio
# 18739   3.0                              lazy porch studio
# 27390   4.0    Airport Studio, King bed. NO CLEANING  FEE.
# 22574   5.0    Airport Studio, King bed. NO CLEANING  FEE.
# 15511   6.0                              lazy porch studio
# 18793   7.0    Airport Studio, King bed. NO CLEANING  FEE.
# 13413   8.0                              lazy porch studio
# 15566   9.0    Airport Studio, King bed. NO CLEANING  FEE.
# 10727  10.0                              lazy porch studio
# 7337   11.0                              lazy porch studio
# 13562  12.0    Airport Studio, King bed. NO CLEANING  FEE.
# 5831   13.0                              lazy porch studio
# 9776   14.0    Airport Studio, King bed. NO CLEANING  FEE.
# 1301   15.0                              lazy porch studio
# 6410   16.0    Airport Studio, King bed. NO CLEANING  FEE.
# 4179   17.0    Airport Studio, King bed. NO CLEANING  FEE.
# 2446   18.0    Airport Studio, King bed. NO CLEANING  FEE.
# 25553  19.0  Airport Haven  with Netflix. NO CLEANING FEE.
# 22004  20.0  Airport Haven  with Netflix. NO CLEANING FEE.
#
#       neighbourhood_group month_year  price  number_of_reviews
# 26541   Christchurch City    2026-06  108.0               1584
# 23613   Christchurch City    2026-05  102.0               1570
# 18739   Christchurch City    2026-04  120.0               1555
# 27390   Christchurch City    2026-06  149.0               1551
# 22574   Christchurch City    2026-05  113.0               1544
# 15511   Christchurch City    2026-03  131.0               1542
# 18793   Christchurch City    2026-04  149.0               1528
# 13413   Christchurch City    2026-02    NaN               1525
# 15566   Christchurch City    2026-03  149.0               1518
# 10727   Christchurch City    2026-01    NaN               1516
# 7337    Christchurch City    2025-12    NaN               1509
# 13562   Christchurch City    2026-02    NaN               1498
# 5831    Christchurch City    2025-11  125.0               1495
# 9776    Christchurch City    2026-01    NaN               1489
# 1301    Christchurch City    2025-10   93.0               1484
# 6410    Christchurch City    2025-12    NaN               1482
# 4179    Christchurch City    2025-11  117.0               1474
# 2446    Christchurch City    2025-10  117.0               1465
# 25553   Christchurch City    2026-06  160.0               1393
# 22004   Christchurch City    2026-05  114.0               1389
